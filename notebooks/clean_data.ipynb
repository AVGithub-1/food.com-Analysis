# %%
import numpy as numpy
import pandas as pd
from sqlalchemy import create_engine

# %%
import mysql.connector

# %%
import os
from dotenv import load_dotenv

load_dotenv()
host = os.getenv('HOST')
user = os.getenv('HOST')
password = os.getenv('HOST')
# Out:
# 'host_avodasvn'

# %%
def connect_to_database(host, user, password, database=None):
    try:
        # Connect to MySQL server and specify the database
        connection = mysql.connector.connect(
            host=host,
            user=user,
            password=password,
            database=database
        )

        #create cursor for the connection
        cursor = connection.cursor()
        
        if connection.is_connected():
            print(f"Connected to MySQL database '{database}'")
            return connection, cursor
    
    except Error as e:
        print(f"Error while connecting to MySQL: {e}")
        return None

# %%
connection, cursor = connect_to_database(host, user, password, database="RecipesDataset")
# Out:
# Connected to MySQL database 'RecipesDataset'

# %%
cursor.execute(f"CREATE DATABASE RecipesDataset")

# %%
df_tags = pd.read_csv("../csv_files/tags.csv")
df_nutr = pd.read_csv("../csv_files/nutrition.csv")
df_steps = pd.read_csv("../csv_files/steps.csv")

# %%
df_nutr = pd.read_csv("../csv_files/nutrition.csv")

# %%
engine.dispose()

# %%
connection.begin().rollback()
# Out:
# ---------------------------------------------------------------------------
# ResourceClosedError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 connection.begin().rollback()
#
# File c:\Users\akhpv\miniconda3\envs\sql_env\lib\site-packages\sqlalchemy\engine\base.py:853, in Connection.begin(self)
#     788 """Begin a transaction prior to autobegin occurring.
#     789
#     790 E.g.::
#    (...)
#     850
#     851 """
#     852 if self._transaction is None:
# --> 853     self._transaction = RootTransaction(self)
#     854     return self._transaction
#     855 else:
#
# File c:\Users\akhpv\miniconda3\envs\sql_env\lib\site-packages\sqlalchemy\engine\base.py:2672, in RootTransaction.__init__(self, connection)
#    2670     TransactionalContext._trans_ctx_check(connection)
#    2671 self.connection = connection
# -> 2672 self._connection_begin_impl()
#    2673 connection._transaction = self
#    2675 self.is_active = True
#
# ...

# %%
connection.execute()

# %%
cursor.execute('DROP Table RecipeTags')

# %%
connection_string = "mysql+mysqlconnector://root:Datab1ses@localhost/recipesdataset"
engine = create_engine(connection_string)

try:
    # Start a connection and transaction
    with engine.connect() as connection:
        with connection.begin():
            # Create the SQL table from the DataFrame
            table_name = 'example_table'
            df_steps.to_sql(table_name, con=connection, if_exists='replace', index=False)
            print(f"Table '{table_name}' created successfully in the database.")
            connection.commit()
except mysql.connector.Error as e:
    print(f"Error: {e}")

# Dispose the engine
engine.dispose()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\akhpv\miniconda3\envs\sql_env\lib\site-packages\mysql\connector\connection_cext.py:639, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     638         query = query.encode("utf-8")
# --> 639     self._cmysql.query(
#     640         query,
#     641         raw=raw,
#     642         buffered=buffered,
#     643         raw_as_string=raw_as_string,
#     644         query_attrs=self.query_attrs,
#     645     )
#     646 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Lost connection to MySQL server during query
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
sql_connection = sql.connect('../recipes_dataset.db')

# %%
sql_connection

# %%
df = pd.read_csv('../csv_files/RAW_recipes.csv')

# %%
df
# Out:
#                                                 name      id  minutes  \
# 0         arriba   baked winter squash mexican style  137739       55
# 1                   a bit different  breakfast pizza   31490       30
# 2                          all in the kitchen  chili  112140      130
# 3                                 alouette  potatoes   59389       45
# 4                 amish  tomato ketchup  for canning   44061      190
# ...                                              ...     ...      ...
# 231632                                   zydeco soup  486161       60
# 231633                              zydeco spice mix  493372        5
# 231634                     zydeco ya ya deviled eggs  308080       40
# 231635        cookies by design   cookies on a stick  298512       29
# 231636  cookies by design   sugar shortbread cookies  298509       20
#
#         contributor_id   submitted  \
# 0                47892  2005-09-16
# 1                26278  2002-06-17
# ...

# %% [markdown]
# # Make 4 tables:
# - tags
# - nutrition
# - steps
# - ingredients

# %%
#tags
df_tags = df[['id','tags']]

# %%
#nutrition
df_nutr = df[['id', 'nutrition']]

# %%
df_nutr
# Out:
#             id                                    nutrition
# 0       137739        [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]
# 1        31490    [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]
# 2       112140   [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]
# 3        59389    [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]
# 4        44061    [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]
# ...        ...                                          ...
# 231632  486161  [415.2, 26.0, 34.0, 26.0, 44.0, 21.0, 15.0]
# 231633  493372        [14.8, 0.0, 2.0, 58.0, 1.0, 0.0, 1.0]
# 231634  308080         [59.2, 6.0, 2.0, 3.0, 6.0, 5.0, 0.0]
# 231635  298512    [188.0, 11.0, 57.0, 11.0, 7.0, 21.0, 9.0]
# 231636  298509     [174.9, 14.0, 33.0, 4.0, 4.0, 11.0, 6.0]
#
# [231637 rows x 2 columns]

# %%
def check_len_nutr(list_nutr):
    if len(list_nutr) == 7:
        return True
    else:
        return False
    
df_nutr_chk = df_nutr['nutrition'].apply(check_len_nutr)

# %%
False in df_nutr_chk
# Out:
# False

# %%
def get_nutr_element(list_nutr, index):
    list_nutr = list_nutr.strip('[]').split(',')
    return list_nutr[index]

# %%
names = ['Calories', 'Total Fat (PDV)', 'Sugar (PDV)' , 'Sodium (PDV)' , 'Protein (PDV)' , 'Saturated Fat (PDV)' , 'Carbohydrates (PDV)']

for i in range(7):
    df_nutr[names[i]] = df_nutr['nutrition'].apply(get_nutr_element, index=i)

df_nutr = df_nutr.drop(labels='nutrition', axis=1)
# Out:
# C:\Users\akhpv\AppData\Local\Temp\ipykernel_20664\4117094944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nutr[names[i]] = df_nutr['nutrition'].apply(get_nutr_element, index=i)
# C:\Users\akhpv\AppData\Local\Temp\ipykernel_20664\4117094944.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nutr[names[i]] = df_nutr['nutrition'].apply(get_nutr_element, index=i)
# C:\Users\akhpv\AppData\Local\Temp\ipykernel_20664\4117094944.py:4: SettingWithCopyWarning:
# ...

# %%
df_nutr
# Out:
#             id Calories Total Fat (PDV) Sugar (PDV) Sodium (PDV)  \
# 0       137739     51.5             0.0        13.0          0.0
# 1        31490    173.4            18.0         0.0         17.0
# 2       112140    269.8            22.0        32.0         48.0
# 3        59389    368.1            17.0        10.0          2.0
# 4        44061    352.9             1.0       337.0         23.0
# ...        ...      ...             ...         ...          ...
# 231632  486161    415.2            26.0        34.0         26.0
# 231633  493372     14.8             0.0         2.0         58.0
# 231634  308080     59.2             6.0         2.0          3.0
# 231635  298512    188.0            11.0        57.0         11.0
# 231636  298509    174.9            14.0        33.0          4.0
#
#        Protein (PDV) Saturated Fat (PDV) Carbohydrates (PDV)
# 0                2.0                 0.0                 4.0
# 1               22.0                35.0                 1.0
# ...

# %%
#steps
df_steps = df[['id', 'n_steps', 'steps']]

# %%
#ingredients
df_ingredients = df[['id', 'n_ingredients', 'ingredients']]
df_ingredients
# Out:
#             id  n_ingredients  \
# 0       137739              7
# 1        31490              6
# 2       112140             13
# 3        59389             11
# 4        44061              8
# ...        ...            ...
# 231632  486161             22
# 231633  493372             13
# 231634  308080              8
# 231635  298512             10
# 231636  298509              7
#
#                                               ingredients
# 0       ['winter squash', 'mexican seasoning', 'mixed ...
# 1       ['prepared pizza crust', 'sausage patty', 'egg...
# 2       ['ground beef', 'yellow onions', 'diced tomato...
# 3       ['spreadable cheese with garlic and herbs', 'n...
# 4       ['tomato juice', 'apple cider vinegar', 'sugar...
# ...                                                   ...
# 231632  ['celery', 'onion', 'green sweet pepper', 'gar...
# 231633  ['paprika', 'salt', 'garlic powder', 'onion po...
# 231634  ['hard-cooked eggs', 'mayonnaise', 'dijon must...
# ...

# %%
max_ing = df_ingredients['n_ingredients'].max()
df_ingredients[df_ingredients['n_ingredients'] == max_ing]
# Out:
#         id  n_ingredients                                        ingredients
# 2162  3748             43  ['sugar', 'vegetable oil', 'eggs', 'vanilla ex...

# %% [markdown]
# Convert the dataframes to CSV files to be imported into MySQL

# %%
df_tags.to_csv('tags.csv')
df_ingredients.to_csv('ingredients.csv')
df_nutr.to_csv('nutrition.csv')
df_steps.to_csv('steps.csv')
